# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.369178
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Becasuse we have 10 classes here, at first our W will be randomly initialized, so it will give rougly equal score for each class, thus the probabily is similar to 0.1, so the loss will be -log(0.1)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 5.439811 analytic: 5.439811, relative error: 1.404831e-08
# numerical: 2.151074 analytic: 2.151074, relative error: 2.473425e-08
# numerical: -0.294738 analytic: -0.294738, relative error: 9.942655e-09
# numerical: -0.247837 analytic: -0.247837, relative error: 9.969276e-09
# numerical: -0.786293 analytic: -0.786293, relative error: 6.782461e-08
# numerical: -3.114570 analytic: -3.114570, relative error: 2.365981e-09
# numerical: 2.242873 analytic: 2.242873, relative error: 2.681918e-08
# numerical: -1.345724 analytic: -1.345724, relative error: 6.958099e-08
# numerical: -0.440218 analytic: -0.440218, relative error: 7.285625e-09
# numerical: 2.498925 analytic: 2.498925, relative error: 9.674110e-09
# numerical: -3.311899 analytic: -3.311899, relative error: 3.679900e-09
# numerical: -1.849005 analytic: -1.849005, relative error: 4.256535e-09
# numerical: -2.313524 analytic: -2.313524, relative error: 9.828682e-09
# numerical: -3.168634 analytic: -3.168634, relative error: 1.627189e-08
# numerical: -2.570175 analytic: -2.570175, relative error: 1.640647e-09
# numerical: -0.902873 analytic: -0.902874, relative error: 6.262713e-08
# numerical: 3.448880 analytic: 3.448880, relative error: 2.476329e-08
# numerical: 3.158631 analytic: 3.158631, relative error: 4.629303e-09
# numerical: -1.651675 analytic: -1.651675, relative error: 3.666634e-09
# numerical: 2.665013 analytic: 2.665013, relative error: 5.739516e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.369178e+00 computed in 0.642122s
# vectorized loss: 2.369178e+00 computed in 0.002907s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
#learning_rates = [1e-7, 5e-7]
#regularization_strengths = [2.5e4, 5e4]
learning_rates = np.arange(1.5e-7, 2.5e-7, 0.1e-7)
regularization_strengths = np.arange(0.9e4, 1e4, 0.01e4)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for i in learning_rates: 
    for j in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train, y_train, i, j, num_iters=1000, verbose=False)
        
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        
        train_acc = np.mean(y_train_pred == y_train)
        val_acc = np.mean(y_val_pred == y_val)
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax
        results[(i,j)] = (train_acc, val_acc)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

ll = []
rr = []
t_acc = []
v_acc = []
for l, r in sorted(results):
    train_acc, val_acc = results[(l, r)]
    ll.append(l)
    rr.append(r)
    t_acc.append(train_acc)
    v_acc.append(val_acc)
    
plt.subplot(2,2,1)
plt.xlabel('learning rate')
plt.ylabel('train accuracy')
plt.plot(ll, t_acc, 'r.')

plt.subplot(2,2,2)
plt.xlabel('regularization rate')
plt.ylabel('train accuracy')
plt.plot(rr, t_acc, 'g.')

plt.subplot(2,2,3)
plt.xlabel('learning rate')
plt.ylabel('val accuracy')
plt.plot(ll, v_acc, 'b.')

plt.subplot(2,2,4)
plt.xlabel('regularization rate')
plt.ylabel('val accuracy')
plt.plot(rr, v_acc, 'y.')

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.500000e-07 reg 9.000000e+03 train accuracy: 0.355755 val accuracy: 0.365000
# lr 1.500000e-07 reg 9.100000e+03 train accuracy: 0.357367 val accuracy: 0.367000
# lr 1.500000e-07 reg 9.200000e+03 train accuracy: 0.352000 val accuracy: 0.375000
# lr 1.500000e-07 reg 9.300000e+03 train accuracy: 0.355143 val accuracy: 0.364000
# lr 1.500000e-07 reg 9.400000e+03 train accuracy: 0.355061 val accuracy: 0.368000
# lr 1.500000e-07 reg 9.500000e+03 train accuracy: 0.356816 val accuracy: 0.357000
# lr 1.500000e-07 reg 9.600000e+03 train accuracy: 0.354367 val accuracy: 0.369000
# lr 1.500000e-07 reg 9.700000e+03 train accuracy: 0.353347 val accuracy: 0.357000
# lr 1.500000e-07 reg 9.800000e+03 train accuracy: 0.353837 val accuracy: 0.356000
# lr 1.500000e-07 reg 9.900000e+03 train accuracy: 0.354612 val accuracy: 0.356000
# lr 1.600000e-07 reg 9.000000e+03 train accuracy: 0.349837 val accuracy: 0.362000
# lr 1.600000e-07 reg 9.100000e+03 train accuracy: 0.352878 val accuracy: 0.367000
# lr 1.600000e-07 reg 9.200000e+03 train accuracy: 0.352306 val accuracy: 0.371000
# lr 1.600000e-07 reg 9.300000e+03 train accuracy: 0.353939 val accuracy: 0.370000
# lr 1.600000e-07 reg 9.400000e+03 train accuracy: 0.355837 val accuracy: 0.367000
# lr 1.600000e-07 reg 9.500000e+03 train accuracy: 0.355163 val accuracy: 0.375000
# lr 1.600000e-07 reg 9.600000e+03 train accuracy: 0.353612 val accuracy: 0.371000
# lr 1.600000e-07 reg 9.700000e+03 train accuracy: 0.353224 val accuracy: 0.352000
# lr 1.600000e-07 reg 9.800000e+03 train accuracy: 0.352510 val accuracy: 0.372000
# lr 1.600000e-07 reg 9.900000e+03 train accuracy: 0.353592 val accuracy: 0.370000
# lr 1.700000e-07 reg 9.000000e+03 train accuracy: 0.357429 val accuracy: 0.383000
# lr 1.700000e-07 reg 9.100000e+03 train accuracy: 0.354143 val accuracy: 0.376000
# lr 1.700000e-07 reg 9.200000e+03 train accuracy: 0.353796 val accuracy: 0.362000
# lr 1.700000e-07 reg 9.300000e+03 train accuracy: 0.356694 val accuracy: 0.370000
# lr 1.700000e-07 reg 9.400000e+03 train accuracy: 0.357694 val accuracy: 0.376000
# lr 1.700000e-07 reg 9.500000e+03 train accuracy: 0.356184 val accuracy: 0.378000
# lr 1.700000e-07 reg 9.600000e+03 train accuracy: 0.356286 val accuracy: 0.372000
# lr 1.700000e-07 reg 9.700000e+03 train accuracy: 0.357510 val accuracy: 0.363000
# lr 1.700000e-07 reg 9.800000e+03 train accuracy: 0.359224 val accuracy: 0.379000
# lr 1.700000e-07 reg 9.900000e+03 train accuracy: 0.355653 val accuracy: 0.363000
# lr 1.800000e-07 reg 9.000000e+03 train accuracy: 0.357816 val accuracy: 0.370000
# lr 1.800000e-07 reg 9.100000e+03 train accuracy: 0.355898 val accuracy: 0.375000
# lr 1.800000e-07 reg 9.200000e+03 train accuracy: 0.357918 val accuracy: 0.358000
# lr 1.800000e-07 reg 9.300000e+03 train accuracy: 0.361163 val accuracy: 0.378000
# lr 1.800000e-07 reg 9.400000e+03 train accuracy: 0.356735 val accuracy: 0.358000
# lr 1.800000e-07 reg 9.500000e+03 train accuracy: 0.358633 val accuracy: 0.367000
# lr 1.800000e-07 reg 9.600000e+03 train accuracy: 0.353469 val accuracy: 0.364000
# lr 1.800000e-07 reg 9.700000e+03 train accuracy: 0.358898 val accuracy: 0.367000
# lr 1.800000e-07 reg 9.800000e+03 train accuracy: 0.358245 val accuracy: 0.378000
# lr 1.800000e-07 reg 9.900000e+03 train accuracy: 0.354469 val accuracy: 0.374000
# lr 1.900000e-07 reg 9.000000e+03 train accuracy: 0.356918 val accuracy: 0.368000
# lr 1.900000e-07 reg 9.100000e+03 train accuracy: 0.354816 val accuracy: 0.365000
# lr 1.900000e-07 reg 9.200000e+03 train accuracy: 0.356735 val accuracy: 0.375000
# lr 1.900000e-07 reg 9.300000e+03 train accuracy: 0.359571 val accuracy: 0.376000
# lr 1.900000e-07 reg 9.400000e+03 train accuracy: 0.357347 val accuracy: 0.363000
# lr 1.900000e-07 reg 9.500000e+03 train accuracy: 0.354918 val accuracy: 0.369000
# lr 1.900000e-07 reg 9.600000e+03 train accuracy: 0.356041 val accuracy: 0.368000
# lr 1.900000e-07 reg 9.700000e+03 train accuracy: 0.354408 val accuracy: 0.368000
# lr 1.900000e-07 reg 9.800000e+03 train accuracy: 0.353959 val accuracy: 0.369000
# lr 1.900000e-07 reg 9.900000e+03 train accuracy: 0.357306 val accuracy: 0.362000
# lr 2.000000e-07 reg 9.000000e+03 train accuracy: 0.357592 val accuracy: 0.364000
# lr 2.000000e-07 reg 9.100000e+03 train accuracy: 0.357735 val accuracy: 0.380000
# lr 2.000000e-07 reg 9.200000e+03 train accuracy: 0.356980 val accuracy: 0.375000
# lr 2.000000e-07 reg 9.300000e+03 train accuracy: 0.356939 val accuracy: 0.366000
# lr 2.000000e-07 reg 9.400000e+03 train accuracy: 0.358510 val accuracy: 0.364000
# lr 2.000000e-07 reg 9.500000e+03 train accuracy: 0.357612 val accuracy: 0.373000
# lr 2.000000e-07 reg 9.600000e+03 train accuracy: 0.358510 val accuracy: 0.371000
# lr 2.000000e-07 reg 9.700000e+03 train accuracy: 0.355082 val accuracy: 0.377000
# lr 2.000000e-07 reg 9.800000e+03 train accuracy: 0.358061 val accuracy: 0.371000
# lr 2.000000e-07 reg 9.900000e+03 train accuracy: 0.357143 val accuracy: 0.365000
# lr 2.100000e-07 reg 9.000000e+03 train accuracy: 0.357776 val accuracy: 0.368000
# lr 2.100000e-07 reg 9.100000e+03 train accuracy: 0.360551 val accuracy: 0.380000
# lr 2.100000e-07 reg 9.200000e+03 train accuracy: 0.355612 val accuracy: 0.373000
# lr 2.100000e-07 reg 9.300000e+03 train accuracy: 0.358959 val accuracy: 0.368000
# lr 2.100000e-07 reg 9.400000e+03 train accuracy: 0.358061 val accuracy: 0.386000
# lr 2.100000e-07 reg 9.500000e+03 train accuracy: 0.357306 val accuracy: 0.366000
# lr 2.100000e-07 reg 9.600000e+03 train accuracy: 0.358571 val accuracy: 0.371000
# lr 2.100000e-07 reg 9.700000e+03 train accuracy: 0.357959 val accuracy: 0.372000
# lr 2.100000e-07 reg 9.800000e+03 train accuracy: 0.353837 val accuracy: 0.369000
# lr 2.100000e-07 reg 9.900000e+03 train accuracy: 0.355633 val accuracy: 0.363000
# lr 2.200000e-07 reg 9.000000e+03 train accuracy: 0.361592 val accuracy: 0.373000
# lr 2.200000e-07 reg 9.100000e+03 train accuracy: 0.360694 val accuracy: 0.377000
# lr 2.200000e-07 reg 9.200000e+03 train accuracy: 0.357449 val accuracy: 0.370000
# lr 2.200000e-07 reg 9.300000e+03 train accuracy: 0.353245 val accuracy: 0.366000
# lr 2.200000e-07 reg 9.400000e+03 train accuracy: 0.356449 val accuracy: 0.368000
# lr 2.200000e-07 reg 9.500000e+03 train accuracy: 0.358857 val accuracy: 0.379000
# lr 2.200000e-07 reg 9.600000e+03 train accuracy: 0.358673 val accuracy: 0.364000
# lr 2.200000e-07 reg 9.700000e+03 train accuracy: 0.356673 val accuracy: 0.368000
# lr 2.200000e-07 reg 9.800000e+03 train accuracy: 0.357735 val accuracy: 0.371000
# lr 2.200000e-07 reg 9.900000e+03 train accuracy: 0.355184 val accuracy: 0.365000
# lr 2.300000e-07 reg 9.000000e+03 train accuracy: 0.358000 val accuracy: 0.365000
# lr 2.300000e-07 reg 9.100000e+03 train accuracy: 0.355673 val accuracy: 0.371000
# lr 2.300000e-07 reg 9.200000e+03 train accuracy: 0.358224 val accuracy: 0.376000
# lr 2.300000e-07 reg 9.300000e+03 train accuracy: 0.358816 val accuracy: 0.383000
# lr 2.300000e-07 reg 9.400000e+03 train accuracy: 0.357837 val accuracy: 0.366000
# lr 2.300000e-07 reg 9.500000e+03 train accuracy: 0.360184 val accuracy: 0.381000
# lr 2.300000e-07 reg 9.600000e+03 train accuracy: 0.359633 val accuracy: 0.367000
# lr 2.300000e-07 reg 9.700000e+03 train accuracy: 0.356082 val accuracy: 0.363000
# lr 2.300000e-07 reg 9.800000e+03 train accuracy: 0.351959 val accuracy: 0.362000
# lr 2.300000e-07 reg 9.900000e+03 train accuracy: 0.354959 val accuracy: 0.369000
# lr 2.400000e-07 reg 9.000000e+03 train accuracy: 0.360531 val accuracy: 0.372000
# lr 2.400000e-07 reg 9.100000e+03 train accuracy: 0.361265 val accuracy: 0.372000
# lr 2.400000e-07 reg 9.200000e+03 train accuracy: 0.360245 val accuracy: 0.385000
# lr 2.400000e-07 reg 9.300000e+03 train accuracy: 0.356857 val accuracy: 0.372000
# lr 2.400000e-07 reg 9.400000e+03 train accuracy: 0.358122 val accuracy: 0.378000
# lr 2.400000e-07 reg 9.500000e+03 train accuracy: 0.355327 val accuracy: 0.369000
# lr 2.400000e-07 reg 9.600000e+03 train accuracy: 0.357469 val accuracy: 0.372000
# lr 2.400000e-07 reg 9.700000e+03 train accuracy: 0.356571 val accuracy: 0.376000
# lr 2.400000e-07 reg 9.800000e+03 train accuracy: 0.359143 val accuracy: 0.365000
# lr 2.400000e-07 reg 9.900000e+03 train accuracy: 0.353184 val accuracy: 0.367000
# best validation accuracy achieved during cross-validation: 0.386000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.356000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
